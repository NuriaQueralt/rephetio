# %%
import sys
import pandas 

# import utils.rawgit()
rawgit = 'https://raw.githubusercontent.com/' 
# local imports
sys.path.insert(0, './data/')

# %% [markdown]
# ### Read DO Slim

# %%
commit = '72614ade9f1cc5a5317b8f6836e1e464b31d5587'
#url = utils.rawgit('dhimmel', 'disease-ontology', commit, 'data/slim-terms.tsv')
url = rawgit + 'dhimmel/' + 'disease-ontology/' + commit + '/data/slim-terms.tsv'
disease_df = pandas.read_table(url)
disease_df = disease_df.rename(columns={'doid': 'doid_id', 'name': 'doid_name'})
disease_df = disease_df[['doid_id', 'doid_name']]
disease_df.head(2)
# Out:
#      doid_id           doid_name
# 0  DOID:2531  Hematologic cancer
# 1  DOID:1319        Brain cancer

# %% [markdown]
# ### Read Entrez Gene

# %%
#commit = '6e133f9ef8ce51a4c5387e58a6cc97564a66cec8'
##url = utils.rawgit('dhimmel', 'entrez-gene', commit, 'data/genes-human.tsv')
#url = rawgit + 'dhimmel/' + 'entrez-gene/' + commit + '/data/genes-human.tsv'
gene_df = pandas.read_table('../entrez-gene/data/genes-human.tsv')
gene_df = gene_df[gene_df.type_of_gene == 'protein-coding']
gene_df = gene_df.rename(columns={'GeneID': 'entrez_gene_id', 'Symbol': 'gene_symbol'})
gene_df = gene_df[['entrez_gene_id', 'gene_symbol']]
gene_df.head(2)
# Out:
#    entrez_gene_id gene_symbol
# 0               1        A1BG
# 1               2         A2M

# %% [markdown]
# ### Read Datasets

# %%
# Orphanet
orphanet_df = pandas.read_table('../data/orphanet-disease-gene.tsv')
orphanet_df = orphanet_df.merge(gene_df, on='gene_symbol', how='left')
orphanet_df.head(2)
# Out:
#    orphanet_code                                  orphanet_term  \
# 0         166024  Multiple epiphyseal dysplasia, Al-Gazali type
# 1             93                         Aspartylglucosaminuria
#
#    orphanet_gene_id  gene_orphanumber                gene_name  \
# 0             20160            268061  kinesin family member 7
# 1             15470            119513  aspartylglucosaminidase
#
#                    gene_type gene_symbol  \
# 0  gene with protein product        KIF7
# 1  gene with protein product         AGA
#
#                                   dga_type dga_status  entrez_gene_id
# 0  Disease-causing germline mutation(s) in   Assessed        374654.0
# 1  Disease-causing germline mutation(s) in   Assessed           175.0

# %%
'{} genes in entrez and {} genes in orphanet'.format(len(gene_df), len(orphanet_df))
# Out:
# '20458 genes in entrez and 6806 genes in orphanet'

# %%
print('gene_types: {}'.format(orphanet_df.gene_type.unique()))
print('dga_status: {}'.format(orphanet_df.dga_status.unique()))
# Out:
# gene_types: ['gene with protein product' 'Non-coding RNA' 'locus']
# dga_status: ['Assessed' 'Not yet assessed']

# %%
# check if there are missing values
orpha_na = orphanet_df.fillna('missing')
orpha_na.query('entrez_gene_id == "missing"')
# Out:
#       orphanet_code                                      orphanet_term  \
# 41              550                                              MELAS
# 42              550                                              MELAS
# 43              550                                              MELAS
# 44              550                                              MELAS
# 45              550                                              MELAS
# 46              550                                              MELAS
# 47              550                                              MELAS
# 48              550                                              MELAS
# 49              550                                              MELAS
# 50              550                                              MELAS
# 51              550                                              MELAS
# 52              550                                              MELAS
# 53              550                                              MELAS
# 54              550                                              MELAS
# 55              269                      Facioscapulohumeral dystrophy
# 60              480                              Kearns-Sayre syndrome
# 61              480                              Kearns-Sayre syndrome
# 63              551                                              MERRF
# 64              551                                              MERRF
# 65              551                                              MERRF
# 66              551                                              MERRF
# 67              551                                              MERRF
# 68              551                                              MERRF
# 69              551                                              MERRF
# 70              551                                              MERRF
# 71              551                                              MERRF
# 72              551                                              MERRF
# 126             803                      Amyotrophic lateral sclerosis
# 145             567                          22q11.2 deletion syndrome
# 197             104                  Leber hereditary optic neuropathy
# ...             ...                                                ...
# 5657          90641  Mitochondrial non-syndromic sensorineural deaf...
# 5658          90641  Mitochondrial non-syndromic sensorineural deaf...
# 5979          96191        Paternal uniparental disomy of chromosome 6
# 5981          96184       Maternal uniparental disomy of chromosome 14
# 5987          96334       Paternal uniparental disomy of chromosome 14
# 6208          99718                                 Leber plus disease
# 6209          99718                                 Leber plus disease
# 6210          99718                                 Leber plus disease
# 6234          98807                       Primary dystonia, DYT13 type
# 6266          98869         Congenital dyserythropoietic anemia type I
# 6287          98890                 Early-onset X-linked optic atrophy
# 6492          98760                      Spinocerebellar ataxia type 8
# 6525         101111                     Spinocerebellar ataxia type 25
# 6528         101110                     Spinocerebellar ataxia type 20
# 6563         101009      Autosomal dominant spastic paraplegia type 29
# 6588         100999      Autosomal dominant spastic paraplegia type 19
# 6590         100997                X-linked spastic paraplegia type 16
# 6592         100995     Autosomal recessive spastic paraplegia type 14
# 6596         101007     Autosomal recessive spastic paraplegia type 27
# 6598         101005     Autosomal recessive spastic paraplegia type 25
# 6600         101003     Autosomal recessive spastic paraplegia type 23
# 6601         101004     Autosomal recessive spastic paraplegia type 24
# 6606         100973                      FRAXE intellectual disability
# 6618         100069                                  Semantic dementia
# 6625         100070                     Progressive non-fluent aphasia
# 6638         100033             Hypomaturation amelogenesis imperfecta
# 6702          99886               Transient neonatal diabetes mellitus
# 6749          99845                    Genetic recurrent myoglobinuria
# 6750          99845                    Genetic recurrent myoglobinuria
# 6765          99852                                    Ravine syndrome
#
#       orphanet_gene_id  gene_orphanumber  \
# 41               16471            123512
# 42               16472            123516
# 43               16473            123520
# 44               16478            123537
# 45               16481            123552
# 46               16483            123562
# 47               16484            123567
# 48               16841            138895
# 49               16844            138906
# 50               17473            160307
# 51               17671            166766
# 52               17722            167901
# 53               17723            167905
# 54               17724            167909
# 55               15901            121239
# 60               16841            138895
# 61               17396            159773
# 63               16483            123562
# 64               16841            138895
# 65               16842            138900
# 66               16843            138902
# 67               16844            138906
# 68               17671            166766
# 69               17722            167901
# 70               17723            167905
# 71               17724            167909
# 72               18493            205934
# 126              20676            286546
# 145              17262            159084
# 197              16470            123508
# ...                ...               ...
# 5657             17671            166766
# 5658             17722            167901
# 5979             17383            159723
# 5981             17275            159158
# 5987             17275            159158
# 6208             16480            123547
# 6209             16481            123552
# 6210             16484            123567
# 6234             17437            160001
# 6266             22273            362774
# 6287             21418            310868
# 6492             17197            158384
# 6525             18725            212612
# 6528             18724            212610
# 6563             18127            180232
# 6588             18121            180213
# 6590             18153            180322
# 6592             18144            180294
# 6596             18150            180316
# 6598             18147            180307
# 6600             18145            180301
# 6601             18139            180270
# 6606             17364            159590
# 6618             20676            286546
# 6625             20676            286546
# 6638             21411            310402
# 6702             17383            159723
# 6749             16471            123512
# 6750             16473            123520
# 6765             22738            398677
#
#                                               gene_name  \
# 41       mitochondrially encoded cytochrome c oxidase I
# 42      mitochondrially encoded cytochrome c oxidase II
# 43     mitochondrially encoded cytochrome c oxidase III
# 44    mitochondrially encoded NADH:ubiquinone oxidor...
# 45    mitochondrially encoded NADH:ubiquinone oxidor...
# 46    mitochondrially encoded NADH:ubiquinone oxidor...
# 47    mitochondrially encoded NADH:ubiquinone oxidor...
# 48       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 49               mitochondrially encoded tRNA glutamine
# 50              mitochondrially encoded tRNA tryptophan
# 51               mitochondrially encoded tRNA histidine
# 52          mitochondrially encoded tRNA serine 1 (UCN)
# 53        mitochondrially encoded tRNA serine 2 (AGU/C)
# 54           mitochondrially encoded tRNA phenylalanine
# 55                             double homeobox 4 like 1
# 60       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 61               mitochondrially encoded ATP synthase 8
# 63    mitochondrially encoded NADH:ubiquinone oxidor...
# 64       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 65                  mitochondrially encoded tRNA lysine
# 66                      mitochondrially encoded 12S RNA
# 67               mitochondrially encoded tRNA glutamine
# 68               mitochondrially encoded tRNA histidine
# 69          mitochondrially encoded tRNA serine 1 (UCN)
# 70        mitochondrially encoded tRNA serine 2 (AGU/C)
# 71           mitochondrially encoded tRNA phenylalanine
# 72                 mitochondrially encoded tRNA proline
# 126                  chromosome 9 open reading frame 72
# 145         ubiquitin fusion degradation 1 like (yeast)
# 197              mitochondrially encoded ATP synthase 6
# ...                                                 ...
# 5657             mitochondrially encoded tRNA histidine
# 5658        mitochondrially encoded tRNA serine 1 (UCN)
# 5979  hydatidiform mole associated and imprinted (no...
# 5981        maternally expressed 3 (non-protein coding)
# 5987        maternally expressed 3 (non-protein coding)
# 6208  mitochondrially encoded NADH:ubiquinone oxidor...
# 6209  mitochondrially encoded NADH:ubiquinone oxidor...
# 6210  mitochondrially encoded NADH:ubiquinone oxidor...
# 6234                               dystonia 13, torsion
# 6266                chromosome 15 open reading frame 41
# 6287                          optic atrophy 2 (obscure)
# 6492         ATXN8 opposite strand (non-protein coding)
# 6525                          spinocerebellar ataxia 25
# 6528                          spinocerebellar ataxia 20
# 6563         spastic paraplegia 29 (autosomal dominant)
# 6588         spastic paraplegia 19 (autosomal dominant)
# 6590  spastic paraplegia 16 (complicated, X-linked r...
# 6592        spastic paraplegia 14 (autosomal recessive)
# 6596        spastic paraplegia 27 (autosomal recessive)
# 6598  spastic paraplegia 25 (autosomal recessive, wi...
# 6600        spastic paraplegia 23 (autosomal recessive)
# 6601        spastic paraplegia 24 (autosomal recessive)
# 6606          fragile X mental retardation associated 3
# 6618                 chromosome 9 open reading frame 72
# 6625                 chromosome 9 open reading frame 72
# 6638                 chromosome 4 open reading frame 26
# 6702  hydatidiform mole associated and imprinted (no...
# 6749     mitochondrially encoded cytochrome c oxidase I
# 6750   mitochondrially encoded cytochrome c oxidase III
# 6765  solute carrier family 7, member 2-intron1 (lon...
#
#                       gene_type gene_symbol  \
# 41    gene with protein product      MT-CO1
# 42    gene with protein product      MT-CO2
# 43    gene with protein product      MT-CO3
# 44    gene with protein product      MT-ND1
# 45    gene with protein product      MT-ND4
# 46    gene with protein product      MT-ND5
# 47    gene with protein product      MT-ND6
# 48               Non-coding RNA      MT-TL1
# 49               Non-coding RNA       MT-TQ
# 50               Non-coding RNA       MT-TW
# 51               Non-coding RNA       MT-TH
# 52               Non-coding RNA      MT-TS1
# 53               Non-coding RNA      MT-TS2
# 54               Non-coding RNA       MT-TF
# 55    gene with protein product      DUX4L1
# 60               Non-coding RNA      MT-TL1
# 61    gene with protein product     MT-ATP8
# 63    gene with protein product      MT-ND5
# 64               Non-coding RNA      MT-TL1
# 65               Non-coding RNA       MT-TK
# 66               Non-coding RNA     MT-RNR1
# 67               Non-coding RNA       MT-TQ
# 68               Non-coding RNA       MT-TH
# 69               Non-coding RNA      MT-TS1
# 70               Non-coding RNA      MT-TS2
# 71               Non-coding RNA       MT-TF
# 72               Non-coding RNA       MT-TP
# 126   gene with protein product     C9ORF72
# 145   gene with protein product       UFD1L
# 197   gene with protein product     MT-ATP6
# ...                         ...         ...
# 5657             Non-coding RNA       MT-TH
# 5658             Non-coding RNA      MT-TS1
# 5979             Non-coding RNA       HYMAI
# 5981             Non-coding RNA        MEG3
# 5987             Non-coding RNA        MEG3
# 6208  gene with protein product      MT-ND3
# 6209  gene with protein product      MT-ND4
# 6210  gene with protein product      MT-ND6
# 6234                      locus       DYT13
# 6266  gene with protein product    C15ORF41
# 6287                      locus        OPA2
# 6492             Non-coding RNA     ATXN8OS
# 6525                      locus       SCA25
# 6528                      locus       SCA20
# 6563                      locus       SPG29
# 6588                      locus       SPG19
# 6590                      locus       SPG16
# 6592                      locus       SPG14
# 6596                      locus       SPG27
# 6598                      locus       SPG25
# 6600                      locus       SPG23
# 6601                      locus       SPG24
# 6606                      locus        FMR3
# 6618  gene with protein product     C9ORF72
# 6625  gene with protein product     C9ORF72
# 6638  gene with protein product     C4ORF26
# 6702             Non-coding RNA       HYMAI
# 6749  gene with protein product      MT-CO1
# 6750  gene with protein product      MT-CO3
# 6765             Non-coding RNA  SLC7A2-IT1
#
#                                                dga_type        dga_status  \
# 41              Disease-causing germline mutation(s) in          Assessed
# 42              Disease-causing germline mutation(s) in          Assessed
# 43                             Candidate gene tested in  Not yet assessed
# 44              Disease-causing germline mutation(s) in          Assessed
# 45              Disease-causing germline mutation(s) in          Assessed
# 46              Disease-causing germline mutation(s) in          Assessed
# 47              Disease-causing germline mutation(s) in          Assessed
# 48              Disease-causing germline mutation(s) in          Assessed
# 49                             Candidate gene tested in  Not yet assessed
# 50              Disease-causing germline mutation(s) in          Assessed
# 51                             Candidate gene tested in  Not yet assessed
# 52              Disease-causing germline mutation(s) in          Assessed
# 53                             Candidate gene tested in  Not yet assessed
# 54              Disease-causing germline mutation(s) in          Assessed
# 55                             Candidate gene tested in  Not yet assessed
# 60                             Candidate gene tested in  Not yet assessed
# 61                             Candidate gene tested in  Not yet assessed
# 63              Disease-causing germline mutation(s) in          Assessed
# 64              Disease-causing germline mutation(s) in          Assessed
# 65              Disease-causing germline mutation(s) in          Assessed
# 66                             Candidate gene tested in  Not yet assessed
# 67                             Candidate gene tested in  Not yet assessed
# 68              Disease-causing germline mutation(s) in          Assessed
# 69              Disease-causing germline mutation(s) in          Assessed
# 70                             Candidate gene tested in  Not yet assessed
# 71              Disease-causing germline mutation(s) in          Assessed
# 72              Disease-causing germline mutation(s) in          Assessed
# 126             Disease-causing germline mutation(s) in          Assessed
# 145                            Role in the phenotype of          Assessed
# 197             Disease-causing germline mutation(s) in          Assessed
# ...                                                 ...               ...
# 5657            Disease-causing germline mutation(s) in          Assessed
# 5658            Disease-causing germline mutation(s) in          Assessed
# 5979                           Role in the phenotype of  Not yet assessed
# 5981                           Role in the phenotype of          Assessed
# 5987                           Role in the phenotype of          Assessed
# 6208            Disease-causing germline mutation(s) in  Not yet assessed
# 6209            Disease-causing germline mutation(s) in  Not yet assessed
# 6210            Disease-causing germline mutation(s) in          Assessed
# 6234            Disease-causing germline mutation(s) in          Assessed
# 6266            Disease-causing germline mutation(s) in          Assessed
# 6287            Disease-causing germline mutation(s) in          Assessed
# 6492            Disease-causing germline mutation(s) in          Assessed
# 6525            Disease-causing germline mutation(s) in          Assessed
# 6528            Disease-causing germline mutation(s) in          Assessed
# 6563            Disease-causing germline mutation(s) in  Not yet assessed
# 6588            Disease-causing germline mutation(s) in          Assessed
# 6590            Disease-causing germline mutation(s) in          Assessed
# 6592            Disease-causing germline mutation(s) in          Assessed
# 6596            Disease-causing germline mutation(s) in          Assessed
# 6598            Disease-causing germline mutation(s) in          Assessed
# 6600            Disease-causing germline mutation(s) in          Assessed
# 6601            Disease-causing germline mutation(s) in          Assessed
# 6606            Disease-causing germline mutation(s) in          Assessed
# 6618                     Major susceptibility factor in  Not yet assessed
# 6625                     Major susceptibility factor in  Not yet assessed
# 6638  Disease-causing germline mutation(s) (loss of ...          Assessed
# 6702            Disease-causing germline mutation(s) in          Assessed
# 6749            Disease-causing germline mutation(s) in          Assessed
# 6750            Disease-causing germline mutation(s) in          Assessed
# 6765            Disease-causing germline mutation(s) in          Assessed
#
#      entrez_gene_id
# 41          missing
# 42          missing
# 43          missing
# 44          missing
# 45          missing
# 46          missing
# 47          missing
# 48          missing
# 49          missing
# 50          missing
# 51          missing
# 52          missing
# 53          missing
# 54          missing
# 55          missing
# 60          missing
# 61          missing
# 63          missing
# 64          missing
# 65          missing
# 66          missing
# 67          missing
# 68          missing
# 69          missing
# 70          missing
# 71          missing
# 72          missing
# 126         missing
# 145         missing
# 197         missing
# ...             ...
# 5657        missing
# 5658        missing
# 5979        missing
# 5981        missing
# 5987        missing
# 6208        missing
# 6209        missing
# 6210        missing
# 6234        missing
# 6266        missing
# 6287        missing
# 6492        missing
# 6525        missing
# 6528        missing
# 6563        missing
# 6588        missing
# 6590        missing
# 6592        missing
# 6596        missing
# 6598        missing
# 6600        missing
# 6601        missing
# 6606        missing
# 6618        missing
# 6625        missing
# 6638        missing
# 6702        missing
# 6749        missing
# 6750        missing
# 6765        missing
#
# [197 rows x 10 columns]

# %%
'NA GeneID: {}'.format(len(orpha_na.query('entrez_gene_id == "missing"')))
# Out:
# 'NA GeneID: 197'

# %%
'NA GeneID for protein codeing: {}'.format(len(orpha_na.query('entrez_gene_id == "missing" and gene_type == "gene with protein product"')))
# Out:
# 'NA GeneID for protein codeing: 88'

# %%
orpha_na.query('entrez_gene_id == "missing" and gene_type == "gene with protein product"').head(2)
# Out:
#     orphanet_code orphanet_term  orphanet_gene_id  gene_orphanumber  \
# 41            550         MELAS             16471            123512
# 42            550         MELAS             16472            123516
#
#                                           gene_name  \
# 41   mitochondrially encoded cytochrome c oxidase I
# 42  mitochondrially encoded cytochrome c oxidase II
#
#                     gene_type gene_symbol  \
# 41  gene with protein product      MT-CO1
# 42  gene with protein product      MT-CO2
#
#                                    dga_type dga_status entrez_gene_id
# 41  Disease-causing germline mutation(s) in   Assessed        missing
# 42  Disease-causing germline mutation(s) in   Assessed        missing

# %%
gene_df.query('gene_symbol == "MT-CO1"')
# Out:
# Empty DataFrame
# Columns: [entrez_gene_id, gene_symbol]
# Index: []

# %%
gene_df.query('entrez_gene_id == 4512')
# Out:
#       entrez_gene_id gene_symbol
# 3622            4512        COX1

# %%
# the problem is that in the web site the officia symbol for entrez:4512 is 'MT-CO1',
# while in the downloaded file is 'COX1' +> try the mapping using biothings

# %%
# Remove genes with missing entrez_gene_id data
orpha_df = orpha_na.query('entrez_gene_id != "missing"')
print('genes pre-removal: {}'.format(len(orpha_na)))
print('genes post-removal: {}'.format(len(orpha_df)))
# Out:
# genes pre-removal: 6806
# genes post-removal: 6609

# %%
# reformat
orpha_df = orpha_df.rename(columns={'orphanet_code': 'doid_id', 'orphanet_term': 'doid_name'})
orpha_df['doid_id'] = 'ORPHA:' + orpha_df['doid_id'].astype(str)
orpha_df.head(2)
# Out:
#         doid_id                                      doid_name  \
# 0  ORPHA:166024  Multiple epiphyseal dysplasia, Al-Gazali type
# 1      ORPHA:93                         Aspartylglucosaminuria
#
#    orphanet_gene_id  gene_orphanumber                gene_name  \
# 0             20160            268061  kinesin family member 7
# 1             15470            119513  aspartylglucosaminidase
#
#                    gene_type gene_symbol  \
# 0  gene with protein product        KIF7
# 1  gene with protein product         AGA
#
#                                   dga_type dga_status entrez_gene_id
# 0  Disease-causing germline mutation(s) in   Assessed         374654
# 1  Disease-causing germline mutation(s) in   Assessed            175

# %%
# DISEASES
commit = 'e0089ef89a56348d7d4e0684a9c51c5747b16237'
#url = utils.rawgit('dhimmel', 'diseases', commit, 'data/merged-slim.tsv')
url = rawgit + 'dhimmel/' + 'diseases/' + commit + '/data/merged-slim.tsv'
diseases_df = pandas.read_table(url)
diseases_df.head(2)
# Out:
#       doid_id        doid_name  entrez_gene_id gene_symbol  score_text  \
# 0  DOID:13223  uterine fibroid              60        ACTB         0.8
# 1  DOID:13223  uterine fibroid              71       ACTG1         0.8
#
#    score_knowledge  score_cosmic  score_distild  score_integrated_no_distild  \
# 0              NaN           NaN            NaN                          0.8
# 1              NaN           NaN            NaN                          0.8
#
#    score_integrated
# 0               0.8
# 1               0.8

# %%
# DOAF
commit = 'bbe1c326aa385416e36d02b144e89e2b99e700b6'
#url = utils.rawgit('dhimmel', 'doaf', commit, 'data/doaf.tsv')
url = rawgit + 'dhimmel/' + 'doaf/' + commit + '/data/doaf.tsv'
doaf_df = pandas.read_table(url)
doaf_df = doaf_df.rename(columns={'doid_code': 'doid_id', 'GeneID': 'entrez_gene_id'})
doaf_df.head(2)
# Out:
#         doid_id     doid_name  entrez_gene_id Symbol  count
# 0  DOID:0001816  angiosarcoma             302  ANXA2      1
# 1  DOID:0001816  angiosarcoma             595  CCND1      1

# %%
# DisGeNET
commit = 'fdc5f42f2da745cbf71d7b4cc5021de5685e4a11'
#url = utils.rawgit('dhimmel', 'disgenet', commit, 'data/consolidated.tsv')
url = rawgit + 'dhimmel/' + 'disgenet/' + commit + '/data/consolidated.tsv'
disgenet_df = pandas.read_table(url)
disgenet_df = disgenet_df.rename(columns={'doid_code': 'doid_id', 'geneId': 'entrez_gene_id'})
disgenet_df.head(2)
# Out:
#         doid_id                      doid_name  entrez_gene_id geneSymbol  \
# 0  DOID:0050156  idiopathic pulmonary fibrosis          729238     SFTPA2
# 1  DOID:0050156  idiopathic pulmonary fibrosis            7015       TERT
#
#    count  pubmeds_max  score_max  score_mean             associationType  \
# 0    1.0          1.0   0.620284    0.620284  Biomarker|GeneticVariation
# 1    1.0         10.0   0.422153    0.422153  Biomarker|GeneticVariation
#
#                                source
# 0    BeFree|CLINVAR|CTD_human|UNIPROT
# 1  BeFree|CLINVAR|CTD_human|GAD|LHGDN

# %%
# hetio GWAS
commit = '0617ea7ea8268f21f5ca1b8dbe487dd12671fc7b'
#url = utils.rawgit('dhimmel', 'gwas-catalog', commit, 'data/gene-associations.tsv')
url = rawgit + 'dhimmel/' + 'gwas-catalog/' + commit + '/data/gene-associations.tsv'
gwas_df = pandas.read_table(url)
gwas_df = gwas_df.rename(columns={'doid_code': 'doid_id', 'gene': 'entrez_gene_id'})
gwas_df.head(2)
# Out:
#      doid_id doid_name  locus  high_confidence  primary status  \
# 0  DOID:9970   obesity      0                1        1   HC-P
# 1  DOID:9970   obesity     14                1        1   HC-P
#
#    entrez_gene_id symbol
# 0            3953   LEPR
# 1            4094    MAF

# %% [markdown]
# ### Filters

# %%
orpha_df = orpha_df.query('gene_type == "gene with protein product" or dga_status == "Assessed"')
diseases_df = diseases_df.query('score_integrated_no_distild >= 2')
doaf_df = doaf_df.query('count >= 3')
disgenet_df = disgenet_df.query('score_max >= 0.06')
gwas_df = gwas_df[gwas_df.status == 'HC-P']

# %% [markdown]
# ### Combine

# %%
orpha_df['provenance'] = 'Orphanet'
diseases_df['provenance'] = 'DISEASES'
doaf_df['provenance'] = 'DOAF'
disgenet_df['provenance'] = 'DisGeNET'
gwas_df['provenance'] = 'GWAS Catalog'

orpha_df['license'] = 'CC BY-ND 3.0'
diseases_df['license'] = 'CC BY 4.0'
doaf_df['license'] = ''
disgenet_df['license'] = 'ODbL 1.0'
gwas_df['license'] = 'CC BY 4.0'

# %%
dfs = [df[['doid_id', 'entrez_gene_id', 'provenance', 'license']]
       for df in (diseases_df, doaf_df, disgenet_df, gwas_df)]
concat_df = pandas.concat(dfs)
concat_df = disease_df.merge(gene_df.merge(concat_df))
concat_df.provenance.value_counts()
# Out:
# DisGeNET        7552
# DISEASES        4990
# DOAF            1649
# GWAS Catalog    1283
# Name: provenance, dtype: int64

# %%
concat_df.head(2)
orpha_df = orpha_df[['doid_id', 'doid_name', 'entrez_gene_id', 'gene_symbol', 'provenance', 'license']]
concat_df = pandas.concat([concat_df,orpha_df])
concat_df.provenance.value_counts()
# Out:
# DisGeNET        7552
# Orphanet        6609
# DISEASES        4990
# DOAF            1649
# GWAS Catalog    1283
# Name: provenance, dtype: int64

# %%
def condense(df):
    """Consolidate multiple associations into a single Series."""
    row = pandas.Series()
    row['sources'] = '|'.join(df.provenance)
    licenses = set(df.license)
    licenses.discard('')
    try:
        row['license'], = licenses
    except ValueError:
        row['license'] = None
    return row

short_df = concat_df.groupby(['doid_id', 'entrez_gene_id']).apply(condense).reset_index()
short_df = disease_df.merge(gene_df.merge(short_df))
short_df.head()
# Out:
#      doid_id           doid_name  entrez_gene_id gene_symbol  \
# 0  DOID:2531  Hematologic cancer              25        ABL1
# 1  DOID:2531  Hematologic cancer              27        ABL2
# 2  DOID:2531  Hematologic cancer              54        ACP5
# 3  DOID:2531  Hematologic cancer             113       ADCY7
# 4  DOID:2531  Hematologic cancer             142       PARP1
#
#              sources    license
# 0  DISEASES|DisGeNET       None
# 1           DisGeNET   ODbL 1.0
# 2           DISEASES  CC BY 4.0
# 3           DisGeNET   ODbL 1.0
# 4  DISEASES|DisGeNET       None

# %%
short_df.to_csv('DaG-association.tsv', sep='\t', index=False)

# %%
short_df = concat_df.groupby(['doid_id', 'entrez_gene_id']).apply(condense).reset_index()

# %%
short_df
# Out:
#             doid_id  entrez_gene_id                              sources  \
# 0      DOID:0050156          1832.0                             DisGeNET
# 1      DOID:0050156          2335.0                             DISEASES
# 2      DOID:0050156          2355.0                             DisGeNET
# 3      DOID:0050156          4088.0                             DISEASES
# 4      DOID:0050156          5328.0                             DisGeNET
# 5      DOID:0050156          6440.0                    DISEASES|DisGeNET
# 6      DOID:0050156          6441.0                             DISEASES
# 7      DOID:0050156          7015.0  DISEASES|DOAF|DisGeNET|GWAS Catalog
# 8      DOID:0050156          7040.0                             DISEASES
# 9      DOID:0050156         10144.0                             DisGeNET
# 10     DOID:0050156         23250.0                             DisGeNET
# 11     DOID:0050156         54472.0                         GWAS Catalog
# 12     DOID:0050156         79991.0                             DisGeNET
# 13     DOID:0050156         91039.0                             DisGeNET
# 14     DOID:0050156        255520.0                    DISEASES|DisGeNET
# 15     DOID:0050156        653509.0                             DisGeNET
# 16     DOID:0050156        727897.0                             DisGeNET
# 17     DOID:0050156        729238.0                    DISEASES|DisGeNET
# 18     DOID:0050425          1775.0                             DISEASES
# 19     DOID:0050425          4211.0       DISEASES|DisGeNET|GWAS Catalog
# 20     DOID:0050425          5348.0                             DISEASES
# 21     DOID:0050425          5443.0                             DisGeNET
# 22     DOID:0050425          5607.0                DISEASES|GWAS Catalog
# 23     DOID:0050425          5789.0       DISEASES|DisGeNET|GWAS Catalog
# 24     DOID:0050425          7018.0                             DisGeNET
# 25     DOID:0050425         27324.0                         GWAS Catalog
# 26     DOID:0050425         51072.0                             DISEASES
# 27     DOID:0050425         94033.0                             DISEASES
# 28     DOID:0050425        114781.0       DISEASES|DisGeNET|GWAS Catalog
# 29     DOID:0050425        348654.0                             DISEASES
# ...             ...             ...                                  ...
# 19175   ORPHA:99943          4359.0                             Orphanet
# 19176   ORPHA:99944         54332.0                             Orphanet
# 19177   ORPHA:99945         26353.0                             Orphanet
# 19178   ORPHA:99946         23095.0                             Orphanet
# 19179   ORPHA:99947          9927.0                             Orphanet
# 19180   ORPHA:99948         54332.0                             Orphanet
# 19181   ORPHA:99949         79628.0                             Orphanet
# 19182   ORPHA:99950         10397.0                             Orphanet
# 19183   ORPHA:99951          1959.0                             Orphanet
# 19184   ORPHA:99952         57716.0                             Orphanet
# 19185   ORPHA:99953          3098.0                             Orphanet
# 19186   ORPHA:99954        121512.0                             Orphanet
# 19187   ORPHA:99955          8898.0                             Orphanet
# 19188   ORPHA:99956         81846.0                             Orphanet
# 19189   ORPHA:99960          5205.0                             Orphanet
# 19190   ORPHA:99961          8647.0                             Orphanet
# 19191   ORPHA:99966          6598.0                             Orphanet
# 19192   ORPHA:99967          1649.0                             Orphanet
# 19193   ORPHA:99967          2521.0                             Orphanet
# 19194   ORPHA:99970          1019.0                             Orphanet
# 19195   ORPHA:99970          4193.0                             Orphanet
# 19196   ORPHA:99970          8091.0                             Orphanet
# 19197   ORPHA:99971          1019.0                             Orphanet
# 19198   ORPHA:99971          4193.0                             Orphanet
# 19199   ORPHA:99971          8091.0                             Orphanet
# 19200   ORPHA:99977          6049.0                             Orphanet
# 19201   ORPHA:99977          7048.0                             Orphanet
# 19202   ORPHA:99977          9940.0                             Orphanet
# 19203   ORPHA:99977         51741.0                             Orphanet
# 19204   ORPHA:99989          3767.0                             Orphanet
#
#             license
# 0          ODbL 1.0
# 1         CC BY 4.0
# 2          ODbL 1.0
# 3         CC BY 4.0
# 4          ODbL 1.0
# 5              None
# 6         CC BY 4.0
# 7              None
# 8         CC BY 4.0
# 9          ODbL 1.0
# 10         ODbL 1.0
# 11        CC BY 4.0
# 12         ODbL 1.0
# 13         ODbL 1.0
# 14             None
# 15         ODbL 1.0
# 16         ODbL 1.0
# 17             None
# 18        CC BY 4.0
# 19             None
# 20        CC BY 4.0
# 21         ODbL 1.0
# 22        CC BY 4.0
# 23             None
# 24         ODbL 1.0
# 25        CC BY 4.0
# 26        CC BY 4.0
# 27        CC BY 4.0
# 28             None
# 29        CC BY 4.0
# ...             ...
# 19175  CC BY-ND 3.0
# 19176  CC BY-ND 3.0
# 19177  CC BY-ND 3.0
# 19178  CC BY-ND 3.0
# 19179  CC BY-ND 3.0
# 19180  CC BY-ND 3.0
# 19181  CC BY-ND 3.0
# 19182  CC BY-ND 3.0
# 19183  CC BY-ND 3.0
# 19184  CC BY-ND 3.0
# 19185  CC BY-ND 3.0
# 19186  CC BY-ND 3.0
# 19187  CC BY-ND 3.0
# 19188  CC BY-ND 3.0
# 19189  CC BY-ND 3.0
# 19190  CC BY-ND 3.0
# 19191  CC BY-ND 3.0
# 19192  CC BY-ND 3.0
# 19193  CC BY-ND 3.0
# 19194  CC BY-ND 3.0
# 19195  CC BY-ND 3.0
# 19196  CC BY-ND 3.0
# 19197  CC BY-ND 3.0
# 19198  CC BY-ND 3.0
# 19199  CC BY-ND 3.0
# 19200  CC BY-ND 3.0
# 19201  CC BY-ND 3.0
# 19202  CC BY-ND 3.0
# 19203  CC BY-ND 3.0
# 19204  CC BY-ND 3.0
#
# [19205 rows x 4 columns]
