# %%
import sys
import pandas 

# import utils.rawgit()
rawgit = 'https://raw.githubusercontent.com/' 
# local imports
sys.path.insert(0, './data/')

# %% [markdown]
# ### Read DO Slim

# %%
commit = '72614ade9f1cc5a5317b8f6836e1e464b31d5587'
#url = utils.rawgit('dhimmel', 'disease-ontology', commit, 'data/slim-terms.tsv')
url = rawgit + 'dhimmel/' + 'disease-ontology/' + commit + '/data/slim-terms.tsv'
disease_df = pandas.read_table(url)
disease_df = disease_df.rename(columns={'doid': 'doid_id', 'name': 'doid_name'})
disease_df = disease_df[['doid_id', 'doid_name']]
disease_df.head(2)
# Out:
#      doid_id           doid_name
# 0  DOID:2531  Hematologic cancer
# 1  DOID:1319        Brain cancer

# %% [markdown]
# ### Read Entrez Gene

# %%
#commit = '6e133f9ef8ce51a4c5387e58a6cc97564a66cec8'
##url = utils.rawgit('dhimmel', 'entrez-gene', commit, 'data/genes-human.tsv')
#url = rawgit + 'dhimmel/' + 'entrez-gene/' + commit + '/data/genes-human.tsv'
gene_df = pandas.read_table('../entrez-gene/data/genes-human.tsv')
gene_df = gene_df[gene_df.type_of_gene == 'protein-coding']
gene_df = gene_df.rename(columns={'GeneID': 'entrez_gene_id', 'Symbol': 'gene_symbol'})
gene_df = gene_df[['entrez_gene_id', 'gene_symbol']]
gene_df.head(2)
# Out:
#    entrez_gene_id gene_symbol
# 0               1        A1BG
# 1               2         A2M

# %% [markdown]
# ### Read Datasets

# %%
# Orphanet
#orphanet_df = pandas.read_table('../data/orphanet-disease-gene.tsv')
orphanet_df = pandas.read_table('../data/orphanet-mondo-disease-gene.tsv')
orphanet_df = orphanet_df.merge(gene_df, on='gene_symbol', how='left')
orphanet_df.head(2)
# Out:
#   orphanet_code                  orphanet_term  orphanet_gene_id  \
# 0  DOID:0050461         Aspartylglucosaminuria             15470
# 1  DOID:0050441  Multiple sulfatase deficiency             15570
#
#    gene_orphanumber                     gene_name                  gene_type  \
# 0            119513       aspartylglucosaminidase  gene with protein product
# 1            119899  sulfatase modifying factor 1  gene with protein product
#
#   gene_symbol                                 dga_type dga_status  \
# 0         AGA  Disease-causing germline mutation(s) in   Assessed
# 1       SUMF1  Disease-causing germline mutation(s) in   Assessed
#
#    entrez_gene_id
# 0           175.0
# 1        285362.0

# %%
'{} genes in entrez and {} genes in orphanet'.format(len(gene_df.gene_symbol.unique()), len(orphanet_df.gene_symbol.unique()))
# Out:
# '20455 genes in entrez and 3641 genes in orphanet'

# %%
print('gene_types: {}'.format(orphanet_df.gene_type.unique()))
print('dga_status: {}'.format(orphanet_df.dga_status.unique()))
# Out:
# gene_types: ['gene with protein product' 'Non-coding RNA' 'locus']
# dga_status: ['Assessed' 'Not yet assessed']

# %%
# check if there are missing values
orpha_na = orphanet_df.fillna('missing')
orpha_na.query('entrez_gene_id == "missing"')
# Out:
#         orphanet_code                                      orphanet_term  \
# 22          DOID:3687                                              MELAS
# 23          DOID:3687                                              MELAS
# 24          DOID:3687                                              MELAS
# 25          DOID:3687                                              MELAS
# 26          DOID:3687                                              MELAS
# 27          DOID:3687                                              MELAS
# 28          DOID:3687                                              MELAS
# 29          DOID:3687                                              MELAS
# 30          DOID:3687                                              MELAS
# 31          DOID:3687                                              MELAS
# 32          DOID:3687                                              MELAS
# 33          DOID:3687                                              MELAS
# 34          DOID:3687                                              MELAS
# 35          DOID:3687                                              MELAS
# 36         DOID:11727                      Facioscapulohumeral dystrophy
# 41         DOID:12934                              Kearns-Sayre syndrome
# 42         DOID:12934                              Kearns-Sayre syndrome
# 44           DOID:310                                              MERRF
# 45           DOID:310                                              MERRF
# 46           DOID:310                                              MERRF
# 47           DOID:310                                              MERRF
# 48           DOID:310                                              MERRF
# 49           DOID:310                                              MERRF
# 50           DOID:310                                              MERRF
# 51           DOID:310                                              MERRF
# 52           DOID:310                                              MERRF
# 53           DOID:310                                              MERRF
# 120          DOID:705                  Leber hereditary optic neuropathy
# 121          DOID:705                  Leber hereditary optic neuropathy
# 122          DOID:705                  Leber hereditary optic neuropathy
# ...               ...                                                ...
# 5054     Orphanet:225         Maternally-inherited diabetes and deafness
# 5108  Orphanet:401901  Huntington disease-like syndrome due to C9ORF7...
# 5178  Orphanet:391646                           Feingold syndrome type 2
# 5205  Orphanet:397959          TCR-alpha-beta-positive T-cell deficiency
# 5217  Orphanet:397750  Periodic paralysis with later-onset distal mot...
# 5218  Orphanet:397750  Periodic paralysis with later-onset distal mot...
# 5426  Orphanet:422526         Hereditary clear cell renal cell carcinoma
# 5456      Orphanet:88                         Idiopathic aplastic anemia
# 5570   Orphanet:65684                               Monomelic amyotrophy
# 5647   Orphanet:75327                   North Carolina macular dystrophy
# 5718   Orphanet:33110                       Autosomal agammaglobulinemia
# 5946   Orphanet:90641  Mitochondrial non-syndromic sensorineural deaf...
# 5947   Orphanet:90641  Mitochondrial non-syndromic sensorineural deaf...
# 5948   Orphanet:90641  Mitochondrial non-syndromic sensorineural deaf...
# 5949   Orphanet:90641  Mitochondrial non-syndromic sensorineural deaf...
# 6197   Orphanet:96191        Paternal uniparental disomy of chromosome 6
# 6199   Orphanet:96184       Maternal uniparental disomy of chromosome 14
# 6205   Orphanet:96334       Paternal uniparental disomy of chromosome 14
# 6407   Orphanet:99718                                 Leber plus disease
# 6408   Orphanet:99718                                 Leber plus disease
# 6409   Orphanet:99718                                 Leber plus disease
# 6453   Orphanet:98869         Congenital dyserythropoietic anemia type I
# 6470   Orphanet:98890                 Early-onset X-linked optic atrophy
# 6663  Orphanet:100973                      FRAXE intellectual disability
# 6675  Orphanet:100069                                  Semantic dementia
# 6682  Orphanet:100070                     Progressive non-fluent aphasia
# 6691  Orphanet:100033             Hypomaturation amelogenesis imperfecta
# 6765   Orphanet:99845                    Genetic recurrent myoglobinuria
# 6766   Orphanet:99845                    Genetic recurrent myoglobinuria
# 6780   Orphanet:99852                                    Ravine syndrome
#
#       orphanet_gene_id  gene_orphanumber  \
# 22               16471            123512
# 23               16472            123516
# 24               16473            123520
# 25               16478            123537
# 26               16481            123552
# 27               16483            123562
# 28               16484            123567
# 29               16841            138895
# 30               16844            138906
# 31               17473            160307
# 32               17671            166766
# 33               17722            167901
# 34               17723            167905
# 35               17724            167909
# 36               15901            121239
# 41               16841            138895
# 42               17396            159773
# 44               16483            123562
# 45               16841            138895
# 46               16842            138900
# 47               16843            138902
# 48               16844            138906
# 49               17671            166766
# 50               17722            167901
# 51               17723            167905
# 52               17724            167909
# 53               18493            205934
# 120              16470            123508
# 121              16471            123512
# 122              16473            123520
# ...                ...               ...
# 5054             16981            140514
# 5108             20676            286546
# 5178             20656            285348
# 5205             22849            401908
# 5217             16470            123508
# 5218             17396            159773
# 5426             21868            326692
# 5456             16790            138457
# 5570             21089            299619
# 5647             23671            455932
# 5718             16247            122591
# 5946             16471            123512
# 5947             16843            138902
# 5948             17671            166766
# 5949             17722            167901
# 6197             17383            159723
# 6199             17275            159158
# 6205             17275            159158
# 6407             16480            123547
# 6408             16481            123552
# 6409             16484            123567
# 6453             22273            362774
# 6470             21418            310868
# 6663             17364            159590
# 6675             20676            286546
# 6682             20676            286546
# 6691             21411            310402
# 6765             16471            123512
# 6766             16473            123520
# 6780             22738            398677
#
#                                               gene_name  \
# 22       mitochondrially encoded cytochrome c oxidase I
# 23      mitochondrially encoded cytochrome c oxidase II
# 24     mitochondrially encoded cytochrome c oxidase III
# 25    mitochondrially encoded NADH:ubiquinone oxidor...
# 26    mitochondrially encoded NADH:ubiquinone oxidor...
# 27    mitochondrially encoded NADH:ubiquinone oxidor...
# 28    mitochondrially encoded NADH:ubiquinone oxidor...
# 29       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 30               mitochondrially encoded tRNA glutamine
# 31              mitochondrially encoded tRNA tryptophan
# 32               mitochondrially encoded tRNA histidine
# 33          mitochondrially encoded tRNA serine 1 (UCN)
# 34        mitochondrially encoded tRNA serine 2 (AGU/C)
# 35           mitochondrially encoded tRNA phenylalanine
# 36                             double homeobox 4 like 1
# 41       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 42               mitochondrially encoded ATP synthase 8
# 44    mitochondrially encoded NADH:ubiquinone oxidor...
# 45       mitochondrially encoded tRNA leucine 1 (UUA/G)
# 46                  mitochondrially encoded tRNA lysine
# 47                      mitochondrially encoded 12S RNA
# 48               mitochondrially encoded tRNA glutamine
# 49               mitochondrially encoded tRNA histidine
# 50          mitochondrially encoded tRNA serine 1 (UCN)
# 51        mitochondrially encoded tRNA serine 2 (AGU/C)
# 52           mitochondrially encoded tRNA phenylalanine
# 53                 mitochondrially encoded tRNA proline
# 120              mitochondrially encoded ATP synthase 6
# 121      mitochondrially encoded cytochrome c oxidase I
# 122    mitochondrially encoded cytochrome c oxidase III
# ...                                                 ...
# 5054         mitochondrially encoded tRNA glutamic acid
# 5108                 chromosome 9 open reading frame 72
# 5178                     miR-17-92a-1 cluster host gene
# 5205                     T-cell receptor alpha constant
# 5217             mitochondrially encoded ATP synthase 6
# 5218             mitochondrially encoded ATP synthase 8
# 5426                     disrupted in renal carcinoma 3
# 5456                           telomerase RNA component
# 5570                 chromosome 5 open reading frame 42
# 5647      DNase1 hypersensitivity, chromosome 6, site 1
# 5718                   immunoglobulin heavy constant mu
# 5946     mitochondrially encoded cytochrome c oxidase I
# 5947                    mitochondrially encoded 12S RNA
# 5948             mitochondrially encoded tRNA histidine
# 5949        mitochondrially encoded tRNA serine 1 (UCN)
# 6197  hydatidiform mole associated and imprinted (no...
# 6199        maternally expressed 3 (non-protein coding)
# 6205        maternally expressed 3 (non-protein coding)
# 6407  mitochondrially encoded NADH:ubiquinone oxidor...
# 6408  mitochondrially encoded NADH:ubiquinone oxidor...
# 6409  mitochondrially encoded NADH:ubiquinone oxidor...
# 6453                chromosome 15 open reading frame 41
# 6470                          optic atrophy 2 (obscure)
# 6663          fragile X mental retardation associated 3
# 6675                 chromosome 9 open reading frame 72
# 6682                 chromosome 9 open reading frame 72
# 6691                 chromosome 4 open reading frame 26
# 6765     mitochondrially encoded cytochrome c oxidase I
# 6766   mitochondrially encoded cytochrome c oxidase III
# 6780  solute carrier family 7, member 2-intron1 (lon...
#
#                       gene_type gene_symbol  \
# 22    gene with protein product      MT-CO1
# 23    gene with protein product      MT-CO2
# 24    gene with protein product      MT-CO3
# 25    gene with protein product      MT-ND1
# 26    gene with protein product      MT-ND4
# 27    gene with protein product      MT-ND5
# 28    gene with protein product      MT-ND6
# 29               Non-coding RNA      MT-TL1
# 30               Non-coding RNA       MT-TQ
# 31               Non-coding RNA       MT-TW
# 32               Non-coding RNA       MT-TH
# 33               Non-coding RNA      MT-TS1
# 34               Non-coding RNA      MT-TS2
# 35               Non-coding RNA       MT-TF
# 36    gene with protein product      DUX4L1
# 41               Non-coding RNA      MT-TL1
# 42    gene with protein product     MT-ATP8
# 44    gene with protein product      MT-ND5
# 45               Non-coding RNA      MT-TL1
# 46               Non-coding RNA       MT-TK
# 47               Non-coding RNA     MT-RNR1
# 48               Non-coding RNA       MT-TQ
# 49               Non-coding RNA       MT-TH
# 50               Non-coding RNA      MT-TS1
# 51               Non-coding RNA      MT-TS2
# 52               Non-coding RNA       MT-TF
# 53               Non-coding RNA       MT-TP
# 120   gene with protein product     MT-ATP6
# 121   gene with protein product      MT-CO1
# 122   gene with protein product      MT-CO3
# ...                         ...         ...
# 5054             Non-coding RNA       MT-TE
# 5108  gene with protein product     C9ORF72
# 5178             Non-coding RNA     MIR17HG
# 5205  gene with protein product        TRAC
# 5217  gene with protein product     MT-ATP6
# 5218  gene with protein product     MT-ATP8
# 5426  gene with protein product       DIRC3
# 5456             Non-coding RNA        TERC
# 5570  gene with protein product     C5ORF42
# 5647                      locus      DHS6S1
# 5718  gene with protein product        IGHM
# 5946  gene with protein product      MT-CO1
# 5947             Non-coding RNA     MT-RNR1
# 5948             Non-coding RNA       MT-TH
# 5949             Non-coding RNA      MT-TS1
# 6197             Non-coding RNA       HYMAI
# 6199             Non-coding RNA        MEG3
# 6205             Non-coding RNA        MEG3
# 6407  gene with protein product      MT-ND3
# 6408  gene with protein product      MT-ND4
# 6409  gene with protein product      MT-ND6
# 6453  gene with protein product    C15ORF41
# 6470                      locus        OPA2
# 6663                      locus        FMR3
# 6675  gene with protein product     C9ORF72
# 6682  gene with protein product     C9ORF72
# 6691  gene with protein product     C4ORF26
# 6765  gene with protein product      MT-CO1
# 6766  gene with protein product      MT-CO3
# 6780             Non-coding RNA  SLC7A2-IT1
#
#                                                dga_type        dga_status  \
# 22              Disease-causing germline mutation(s) in          Assessed
# 23              Disease-causing germline mutation(s) in          Assessed
# 24                             Candidate gene tested in  Not yet assessed
# 25              Disease-causing germline mutation(s) in          Assessed
# 26              Disease-causing germline mutation(s) in          Assessed
# 27              Disease-causing germline mutation(s) in          Assessed
# 28              Disease-causing germline mutation(s) in          Assessed
# 29              Disease-causing germline mutation(s) in          Assessed
# 30                             Candidate gene tested in  Not yet assessed
# 31              Disease-causing germline mutation(s) in          Assessed
# 32                             Candidate gene tested in  Not yet assessed
# 33              Disease-causing germline mutation(s) in          Assessed
# 34                             Candidate gene tested in  Not yet assessed
# 35              Disease-causing germline mutation(s) in          Assessed
# 36                             Candidate gene tested in  Not yet assessed
# 41                             Candidate gene tested in  Not yet assessed
# 42                             Candidate gene tested in  Not yet assessed
# 44              Disease-causing germline mutation(s) in          Assessed
# 45              Disease-causing germline mutation(s) in          Assessed
# 46              Disease-causing germline mutation(s) in          Assessed
# 47                             Candidate gene tested in  Not yet assessed
# 48                             Candidate gene tested in  Not yet assessed
# 49              Disease-causing germline mutation(s) in          Assessed
# 50              Disease-causing germline mutation(s) in          Assessed
# 51                             Candidate gene tested in  Not yet assessed
# 52              Disease-causing germline mutation(s) in          Assessed
# 53              Disease-causing germline mutation(s) in          Assessed
# 120             Disease-causing germline mutation(s) in          Assessed
# 121                            Candidate gene tested in  Not yet assessed
# 122             Disease-causing germline mutation(s) in          Assessed
# ...                                                 ...               ...
# 5054            Disease-causing germline mutation(s) in          Assessed
# 5108            Disease-causing germline mutation(s) in          Assessed
# 5178                           Role in the phenotype of          Assessed
# 5205            Disease-causing germline mutation(s) in          Assessed
# 5217            Disease-causing germline mutation(s) in          Assessed
# 5218            Disease-causing germline mutation(s) in          Assessed
# 5426                           Part of a fusion gene in          Assessed
# 5456                     Major susceptibility factor in          Assessed
# 5570                     Major susceptibility factor in          Assessed
# 5647            Disease-causing germline mutation(s) in          Assessed
# 5718            Disease-causing germline mutation(s) in          Assessed
# 5946            Disease-causing germline mutation(s) in          Assessed
# 5947            Disease-causing germline mutation(s) in          Assessed
# 5948            Disease-causing germline mutation(s) in          Assessed
# 5949            Disease-causing germline mutation(s) in          Assessed
# 6197                           Role in the phenotype of  Not yet assessed
# 6199                           Role in the phenotype of          Assessed
# 6205                           Role in the phenotype of          Assessed
# 6407            Disease-causing germline mutation(s) in  Not yet assessed
# 6408            Disease-causing germline mutation(s) in  Not yet assessed
# 6409            Disease-causing germline mutation(s) in          Assessed
# 6453            Disease-causing germline mutation(s) in          Assessed
# 6470            Disease-causing germline mutation(s) in          Assessed
# 6663            Disease-causing germline mutation(s) in          Assessed
# 6675                     Major susceptibility factor in  Not yet assessed
# 6682                     Major susceptibility factor in  Not yet assessed
# 6691  Disease-causing germline mutation(s) (loss of ...          Assessed
# 6765            Disease-causing germline mutation(s) in          Assessed
# 6766            Disease-causing germline mutation(s) in          Assessed
# 6780            Disease-causing germline mutation(s) in          Assessed
#
#      entrez_gene_id
# 22          missing
# 23          missing
# 24          missing
# 25          missing
# 26          missing
# 27          missing
# 28          missing
# 29          missing
# 30          missing
# 31          missing
# 32          missing
# 33          missing
# 34          missing
# 35          missing
# 36          missing
# 41          missing
# 42          missing
# 44          missing
# 45          missing
# 46          missing
# 47          missing
# 48          missing
# 49          missing
# 50          missing
# 51          missing
# 52          missing
# 53          missing
# 120         missing
# 121         missing
# 122         missing
# ...             ...
# 5054        missing
# 5108        missing
# 5178        missing
# 5205        missing
# 5217        missing
# 5218        missing
# 5426        missing
# 5456        missing
# 5570        missing
# 5647        missing
# 5718        missing
# 5946        missing
# 5947        missing
# 5948        missing
# 5949        missing
# 6197        missing
# 6199        missing
# 6205        missing
# 6407        missing
# 6408        missing
# 6409        missing
# 6453        missing
# 6470        missing
# 6663        missing
# 6675        missing
# 6682        missing
# 6691        missing
# 6765        missing
# 6766        missing
# 6780        missing
#
# [197 rows x 10 columns]

# %%
'NA GeneID: {}'.format(len(orpha_na.query('entrez_gene_id == "missing"')))
# Out:
# 'NA GeneID: 197'

# %%
'NA GeneID for protein codeing: {}'.format(len(orpha_na.query('entrez_gene_id == "missing" and gene_type == "gene with protein product"')))
# Out:
# 'NA GeneID for protein codeing: 88'

# %%
orpha_na.query('entrez_gene_id == "missing" and gene_type == "gene with protein product"').head(2)
# Out:
#    orphanet_code orphanet_term  orphanet_gene_id  gene_orphanumber  \
# 22     DOID:3687         MELAS             16471            123512
# 23     DOID:3687         MELAS             16472            123516
#
#                                           gene_name  \
# 22   mitochondrially encoded cytochrome c oxidase I
# 23  mitochondrially encoded cytochrome c oxidase II
#
#                     gene_type gene_symbol  \
# 22  gene with protein product      MT-CO1
# 23  gene with protein product      MT-CO2
#
#                                    dga_type dga_status entrez_gene_id
# 22  Disease-causing germline mutation(s) in   Assessed        missing
# 23  Disease-causing germline mutation(s) in   Assessed        missing

# %%
gene_df.query('gene_symbol == "MT-CO1"')
# Out:
# Empty DataFrame
# Columns: [entrez_gene_id, gene_symbol]
# Index: []

# %%
gene_df.query('entrez_gene_id == 4512')
# Out:
#       entrez_gene_id gene_symbol
# 3622            4512        COX1

# %%
# the problem is that in the web site the officia symbol for entrez:4512 is 'MT-CO1',
# while in the downloaded file is 'COX1' +> try the mapping using biothings

# %%
# Remove genes with missing entrez_gene_id data
orpha_df = orpha_na.query('entrez_gene_id != "missing"')
print('genes pre-removal: {}'.format(len(orpha_na)))
print('genes post-removal: {}'.format(len(orpha_df)))
# Out:
# genes pre-removal: 6806
# genes post-removal: 6609

# %%
# reformat
orpha_df = orpha_df.rename(columns={'orphanet_code': 'doid_id', 'orphanet_term': 'doid_name'})
#orpha_df['doid_id'] = 'ORPHA:' + orpha_df['doid_id'].astype(str)
orpha_df.head(2)
# Out:
#         doid_id                      doid_name  orphanet_gene_id  \
# 0  DOID:0050461         Aspartylglucosaminuria             15470
# 1  DOID:0050441  Multiple sulfatase deficiency             15570
#
#    gene_orphanumber                     gene_name                  gene_type  \
# 0            119513       aspartylglucosaminidase  gene with protein product
# 1            119899  sulfatase modifying factor 1  gene with protein product
#
#   gene_symbol                                 dga_type dga_status  \
# 0         AGA  Disease-causing germline mutation(s) in   Assessed
# 1       SUMF1  Disease-causing germline mutation(s) in   Assessed
#
#   entrez_gene_id
# 0            175
# 1         285362

# %%
# DISEASES
commit = 'e0089ef89a56348d7d4e0684a9c51c5747b16237'
#url = utils.rawgit('dhimmel', 'diseases', commit, 'data/merged-slim.tsv')
url = rawgit + 'dhimmel/' + 'diseases/' + commit + '/data/merged-slim.tsv'
diseases_df = pandas.read_table(url)
diseases_df.head(2)
# Out:
#       doid_id        doid_name  entrez_gene_id gene_symbol  score_text  \
# 0  DOID:13223  uterine fibroid              60        ACTB         0.8
# 1  DOID:13223  uterine fibroid              71       ACTG1         0.8
#
#    score_knowledge  score_cosmic  score_distild  score_integrated_no_distild  \
# 0              NaN           NaN            NaN                          0.8
# 1              NaN           NaN            NaN                          0.8
#
#    score_integrated
# 0               0.8
# 1               0.8

# %%
# DOAF
commit = 'bbe1c326aa385416e36d02b144e89e2b99e700b6'
#url = utils.rawgit('dhimmel', 'doaf', commit, 'data/doaf.tsv')
url = rawgit + 'dhimmel/' + 'doaf/' + commit + '/data/doaf.tsv'
doaf_df = pandas.read_table(url)
doaf_df = doaf_df.rename(columns={'doid_code': 'doid_id', 'GeneID': 'entrez_gene_id'})
doaf_df.head(2)
# Out:
#         doid_id     doid_name  entrez_gene_id Symbol  count
# 0  DOID:0001816  angiosarcoma             302  ANXA2      1
# 1  DOID:0001816  angiosarcoma             595  CCND1      1

# %%
# DisGeNET
commit = 'fdc5f42f2da745cbf71d7b4cc5021de5685e4a11'
#url = utils.rawgit('dhimmel', 'disgenet', commit, 'data/consolidated.tsv')
url = rawgit + 'dhimmel/' + 'disgenet/' + commit + '/data/consolidated.tsv'
disgenet_df = pandas.read_table(url)
disgenet_df = disgenet_df.rename(columns={'doid_code': 'doid_id', 'geneId': 'entrez_gene_id'})
disgenet_df.head(2)
# Out:
#         doid_id                      doid_name  entrez_gene_id geneSymbol  \
# 0  DOID:0050156  idiopathic pulmonary fibrosis          729238     SFTPA2
# 1  DOID:0050156  idiopathic pulmonary fibrosis            7015       TERT
#
#    count  pubmeds_max  score_max  score_mean             associationType  \
# 0    1.0          1.0   0.620284    0.620284  Biomarker|GeneticVariation
# 1    1.0         10.0   0.422153    0.422153  Biomarker|GeneticVariation
#
#                                source
# 0    BeFree|CLINVAR|CTD_human|UNIPROT
# 1  BeFree|CLINVAR|CTD_human|GAD|LHGDN

# %%
# hetio GWAS
commit = '0617ea7ea8268f21f5ca1b8dbe487dd12671fc7b'
#url = utils.rawgit('dhimmel', 'gwas-catalog', commit, 'data/gene-associations.tsv')
url = rawgit + 'dhimmel/' + 'gwas-catalog/' + commit + '/data/gene-associations.tsv'
gwas_df = pandas.read_table(url)
gwas_df = gwas_df.rename(columns={'doid_code': 'doid_id', 'gene': 'entrez_gene_id'})
gwas_df.head(2)
# Out:
#      doid_id doid_name  locus  high_confidence  primary status  \
# 0  DOID:9970   obesity      0                1        1   HC-P
# 1  DOID:9970   obesity     14                1        1   HC-P
#
#    entrez_gene_id symbol
# 0            3953   LEPR
# 1            4094    MAF

# %% [markdown]
# ### Filters

# %%
orpha_df = orpha_df.query('gene_type == "gene with protein product" or dga_status == "Assessed"')
diseases_df = diseases_df.query('score_integrated_no_distild >= 2')
doaf_df = doaf_df.query('count >= 3')
disgenet_df = disgenet_df.query('score_max >= 0.06')
gwas_df = gwas_df[gwas_df.status == 'HC-P']

# %% [markdown]
# ### Combine

# %%
orpha_df['provenance'] = 'Orphanet'
diseases_df['provenance'] = 'DISEASES'
doaf_df['provenance'] = 'DOAF'
disgenet_df['provenance'] = 'DisGeNET'
gwas_df['provenance'] = 'GWAS Catalog'

orpha_df['license'] = 'CC BY-ND 3.0'
diseases_df['license'] = 'CC BY 4.0'
doaf_df['license'] = ''
disgenet_df['license'] = 'ODbL 1.0'
gwas_df['license'] = 'CC BY 4.0'

# %%
dfs = [df[['doid_id', 'entrez_gene_id', 'provenance', 'license']]
       for df in (diseases_df, doaf_df, disgenet_df, gwas_df)]
concat_df = pandas.concat(dfs)
concat_df = disease_df.merge(gene_df.merge(concat_df))
concat_df.provenance.value_counts()
# Out:
# DisGeNET        7552
# DISEASES        4990
# DOAF            1649
# GWAS Catalog    1283
# Name: provenance, dtype: int64

# %%
concat_df.head(2)
orpha_df = orpha_df[['doid_id', 'doid_name', 'entrez_gene_id', 'gene_symbol', 'provenance', 'license']]
concat_df = pandas.concat([concat_df,orpha_df])
concat_df.provenance.value_counts()
# Out:
# DisGeNET        7552
# Orphanet        6609
# DISEASES        4990
# DOAF            1649
# GWAS Catalog    1283
# Name: provenance, dtype: int64

# %%
def condense(df):
    """Consolidate multiple associations into a single Series."""
    row = pandas.Series()
    row['sources'] = '|'.join(df.provenance)
    licenses = set(df.license)
    licenses.discard('')
    try:
        row['license'], = licenses
    except ValueError:
        row['license'] = None
    return row

short_df = concat_df.groupby(['doid_id', 'entrez_gene_id']).apply(condense).reset_index()
short_df = disease_df.merge(gene_df.merge(short_df))
short_df.head()
# Out:
#      doid_id           doid_name  entrez_gene_id gene_symbol  \
# 0  DOID:2531  Hematologic cancer              25        ABL1
# 1  DOID:2531  Hematologic cancer              27        ABL2
# 2  DOID:2531  Hematologic cancer              54        ACP5
# 3  DOID:2531  Hematologic cancer             113       ADCY7
# 4  DOID:2531  Hematologic cancer             142       PARP1
#
#              sources    license
# 0  DISEASES|DisGeNET       None
# 1           DisGeNET   ODbL 1.0
# 2           DISEASES  CC BY 4.0
# 3           DisGeNET   ODbL 1.0
# 4  DISEASES|DisGeNET       None

# %%
short_df.to_csv('DaG-association.tsv', sep='\t', index=False)

# %%
short_df = concat_df.groupby(['doid_id', 'entrez_gene_id']).apply(condense).reset_index()

# %%
short_df
# Out:
#               doid_id  entrez_gene_id  \
# 0        DOID:0050156          1832.0
# 1        DOID:0050156          2335.0
# 2        DOID:0050156          2355.0
# 3        DOID:0050156          4088.0
# 4        DOID:0050156          5073.0
# 5        DOID:0050156          5328.0
# 6        DOID:0050156          6440.0
# 7        DOID:0050156          6441.0
# 8        DOID:0050156          7015.0
# 9        DOID:0050156          7040.0
# 10       DOID:0050156         10144.0
# 11       DOID:0050156         23250.0
# 12       DOID:0050156         51750.0
# 13       DOID:0050156         54472.0
# 14       DOID:0050156         79991.0
# 15       DOID:0050156         91039.0
# 16       DOID:0050156        255520.0
# 17       DOID:0050156        653509.0
# 18       DOID:0050156        727897.0
# 19       DOID:0050156        729238.0
# 20       DOID:0050167           326.0
# 21       DOID:0050331          2255.0
# 22       DOID:0050331          2261.0
# 23       DOID:0050331          2263.0
# 24       DOID:0050335          8787.0
# 25       DOID:0050335        388531.0
# 26       DOID:0050425          1775.0
# 27       DOID:0050425          4211.0
# 28       DOID:0050425          5348.0
# 29       DOID:0050425          5443.0
# ...               ...             ...
# 19143  Orphanet:99861          6965.0
# 19144  Orphanet:99861          8028.0
# 19145  Orphanet:99861          8115.0
# 19146  Orphanet:99861          8301.0
# 19147  Orphanet:99861         30012.0
# 19148  Orphanet:99872           673.0
# 19149  Orphanet:99875          1277.0
# 19150  Orphanet:99876          1278.0
# 19151  Orphanet:99879          4221.0
# 19152  Orphanet:99879         79577.0
# 19153  Orphanet:99880         79577.0
# 19154  Orphanet:99887          2623.0
# 19155  Orphanet:99898          3459.0
# 19156  Orphanet:99900            33.0
# 19157  Orphanet:99901         28976.0
# 19158  Orphanet:99914         23405.0
# 19159  Orphanet:99916         23405.0
# 19160  Orphanet:99944         54332.0
# 19161  Orphanet:99960          5205.0
# 19162  Orphanet:99961          8647.0
# 19163  Orphanet:99966          6598.0
# 19164  Orphanet:99967          1649.0
# 19165  Orphanet:99967          2521.0
# 19166  Orphanet:99970          1019.0
# 19167  Orphanet:99970          4193.0
# 19168  Orphanet:99970          8091.0
# 19169  Orphanet:99971          1019.0
# 19170  Orphanet:99971          4193.0
# 19171  Orphanet:99971          8091.0
# 19172  Orphanet:99989          3767.0
#
#                                             sources       license
# 0                                 DisGeNET|Orphanet          None
# 1                                          DISEASES     CC BY 4.0
# 2                                          DisGeNET      ODbL 1.0
# 3                                          DISEASES     CC BY 4.0
# 4                                          Orphanet  CC BY-ND 3.0
# 5                                          DisGeNET      ODbL 1.0
# 6                        DISEASES|DisGeNET|Orphanet          None
# 7                                          DISEASES     CC BY 4.0
# 8      DISEASES|DOAF|DisGeNET|GWAS Catalog|Orphanet          None
# 9                                          DISEASES     CC BY 4.0
# 10                                DisGeNET|Orphanet          None
# 11                                DisGeNET|Orphanet          None
# 12                                         Orphanet  CC BY-ND 3.0
# 13                                     GWAS Catalog     CC BY 4.0
# 14                                DisGeNET|Orphanet          None
# 15                                DisGeNET|Orphanet          None
# 16                                DISEASES|DisGeNET          None
# 17                                DisGeNET|Orphanet          None
# 18                                DisGeNET|Orphanet          None
# 19                       DISEASES|DisGeNET|Orphanet          None
# 20                                         Orphanet  CC BY-ND 3.0
# 21                                         Orphanet  CC BY-ND 3.0
# 22                                         Orphanet  CC BY-ND 3.0
# 23                                         Orphanet  CC BY-ND 3.0
# 24                                         Orphanet  CC BY-ND 3.0
# 25                                         Orphanet  CC BY-ND 3.0
# 26                                         DISEASES     CC BY 4.0
# 27                   DISEASES|DisGeNET|GWAS Catalog          None
# 28                                         DISEASES     CC BY 4.0
# 29                                         DisGeNET      ODbL 1.0
# ...                                             ...           ...
# 19143                                      Orphanet  CC BY-ND 3.0
# 19144                                      Orphanet  CC BY-ND 3.0
# 19145                                      Orphanet  CC BY-ND 3.0
# 19146                                      Orphanet  CC BY-ND 3.0
# 19147                                      Orphanet  CC BY-ND 3.0
# 19148                                      Orphanet  CC BY-ND 3.0
# 19149                                      Orphanet  CC BY-ND 3.0
# 19150                                      Orphanet  CC BY-ND 3.0
# 19151                                      Orphanet  CC BY-ND 3.0
# 19152                                      Orphanet  CC BY-ND 3.0
# 19153                                      Orphanet  CC BY-ND 3.0
# 19154                                      Orphanet  CC BY-ND 3.0
# 19155                                      Orphanet  CC BY-ND 3.0
# 19156                                      Orphanet  CC BY-ND 3.0
# 19157                                      Orphanet  CC BY-ND 3.0
# 19158                                      Orphanet  CC BY-ND 3.0
# 19159                                      Orphanet  CC BY-ND 3.0
# 19160                                      Orphanet  CC BY-ND 3.0
# 19161                                      Orphanet  CC BY-ND 3.0
# 19162                                      Orphanet  CC BY-ND 3.0
# 19163                                      Orphanet  CC BY-ND 3.0
# 19164                                      Orphanet  CC BY-ND 3.0
# 19165                                      Orphanet  CC BY-ND 3.0
# 19166                                      Orphanet  CC BY-ND 3.0
# 19167                                      Orphanet  CC BY-ND 3.0
# 19168                                      Orphanet  CC BY-ND 3.0
# 19169                                      Orphanet  CC BY-ND 3.0
# 19170                                      Orphanet  CC BY-ND 3.0
# 19171                                      Orphanet  CC BY-ND 3.0
# 19172                                      Orphanet  CC BY-ND 3.0
#
# [19173 rows x 4 columns]
